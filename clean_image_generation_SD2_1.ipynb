# %% [markdown]
# # Stable Diffusion 2.1 Dataset Generation

# %%
# !pip install -q diffusers transformers accelerate
# !pip install -q xformers torch torchvision lpips
# !pip install -q kornia scikit-image scikit-learn
# !pip install -q scipy opencv-python
# !pip install -q colormath scipy
# !pip install -U diffusers
# !pip install -U safetensors pillow tqdm pandas
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for colormath (setup.py) ... done
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (0.35.2)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers) (3.20.0)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.35.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers) (0.6.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers) (11.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.34.0->diffusers) (1.1.10)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers) (2025.10.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (0.6.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Collecting pillow
#   Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 91.5 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 103.2 MB/s eta 0:00:00
# Installing collected packages: pillow, pandas
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# gradio 5.49.1 requires pillow<12.0,>=8.0, but you have pillow 12.0.0 which is incompatible.
# Successfully installed pandas-2.3.3 pillow-12.0.0

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Hugging Face prompts dataset ({'train': (73718, 1), 'test': (8192, 1)})
from datasets import load_dataset

ds = load_dataset("Gustavosta/Stable-Diffusion-Prompts")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/777 [00:00<?, ?B/s]
# data/train.parquet:   0%|          | 0.00/9.23M [00:00<?, ?B/s]
# data/eval.parquet:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/73718 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/8192 [00:00<?, ? examples/s]

# %%
import pandas as pd
import numpy as np

hf_prompts_df = pd.DataFrame(ds['train'])
hf_prompts_df = hf_prompts_df.sample(frac=1).reset_index(drop=True)
hf_prompts_df['prompt_length'] = hf_prompts_df['Prompt'].apply(lambda x: len(x))

# %%
hf_prompts_df.to_csv('hf_prompts.csv', index=False)

# %%
hf_prompts_df
# Out:
#                                                   Prompt  prompt_length
# 0      Concept art sketch ninja warrior, anime, volum...            295
# 1      a bunny made of mirrors in a forest. highly de...            168
# 2      a golden woman, eyes closed, glowing lavender ...            177
# 3      fall gnomes svg vector, detailed, concept art,...            205
# 4      a highly detailed epic cinematic concept art C...            481
# ...                                                  ...            ...
# 73713  ancient alien portal, crowd of androids, beams...            200
# 73714  intricate oil painting of barrack obama eating...            201
# 73715  a beautiful illustration of a satanic altar in...            224
# 73716  ( ( ( ( ( hyperrealist distant portrait of sha...            383
# 73717  Portrait of Friedrich Nietzsche in his Suit, c...            231
#
# [73718 rows x 2 columns]

# %%
import os, hashlib, pandas as pd, torch
from tqdm.auto import tqdm
from PIL import Image
from diffusers import StableDiffusionPipeline, EulerAncestralDiscreteScheduler

# %%
MODEL_ID     = "stabilityai/stable-diffusion-2-1-base"
HEIGHT, WIDTH = 512, 512
STEPS        = 50
GUIDANCE     = 7.5
SCHEDULER    = "EulerA"
N_SAMPLES    = 1000
RANDOM_SEED  = 261
PROMPT_COL   = "Prompt"
USE_SAFETY_CHECKER = False

OUT_DIR      = "/content/sd21_images"
OUT_512_DIR  = os.path.join(OUT_DIR, "512x512")
OUT_400_DIR  = os.path.join(OUT_DIR, "400x400")
os.makedirs(OUT_512_DIR, exist_ok=True)
os.makedirs(OUT_400_DIR, exist_ok=True)

# %%
# Selecting a sample of 1000 prompts

df = hf_prompts_df[(hf_prompts_df['prompt_length'] < 500) & (hf_prompts_df['prompt_length'] > 200)]

gsel = df.sample(frac=1.0, random_state=RANDOM_SEED).head(N_SAMPLES).reset_index(drop=True)
prompts = gsel[PROMPT_COL].astype(str).str.strip().tolist()

def seed_from_text(t: str) -> int:
    return int(hashlib.sha256(t.encode("utf-8")).hexdigest()[:8], 16)

pairs = [{"id": i, "prompt": p, "seed": seed_from_text(p)} for i, p in enumerate(prompts)]

# %%
# addinf column of length of prompt for filtering
gsel['prompt_length'] = gsel['Prompt'].apply(lambda x: len(x))

# %%
gsel.to_csv('filtered_prompts.csv', index=False)

# %%
# Load SD 2.1 pipeline (fp16)
pipe = StableDiffusionPipeline.from_pretrained(
    MODEL_ID,
    torch_dtype=torch.float16,
    safety_checker=None if not USE_SAFETY_CHECKER else None,
    use_safetensors=True
)

pipe.scheduler = EulerAncestralDiscreteScheduler.from_config(pipe.scheduler.config)

if torch.cuda.is_available():
    pipe = pipe.to("cuda")
    pipe.enable_attention_slicing()
    try:
        pipe.enable_xformers_memory_efficient_attention()
    except Exception:
        pass
else:
    print("CUDA not found")
# Out:
# model_index.json:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# scheduler_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/807 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# text_encoder/model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# unet/diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
# Saving stable diffusion pipeline components
SAVE_DIR = "/content/drive/MyDrive/Colab Notebooks/Watermarking/models/sd21_base_pipe"
pipe.save_pretrained(SAVE_DIR)

# %%
# Image Generation

manifest_rows = []
pipe.set_progress_bar_config(disable=True)

with torch.inference_mode():
    for item in tqdm(pairs, total=len(pairs), desc="Generating SD2.1 images"):
        gen = torch.Generator(device=pipe.device).manual_seed(item["seed"])
        result = pipe(
            prompt=item["prompt"],
            num_inference_steps=STEPS,
            guidance_scale=GUIDANCE,
            height=HEIGHT, width=WIDTH,
            generator=gen
        )
        img = result.images[0]

        fname_512 = f"{item['id']:06d}_{item['seed']}.png"
        fpath_512 = os.path.join(OUT_512_DIR, fname_512)
        img.save(fpath_512, format="PNG")

        # saving 400x400 images for StegaStamp watermark encoding
        img_400 = img.resize((400, 400), resample=Image.LANCZOS)
        fname_400 = f"{item['id']:06d}_{item['seed']}_400.png"
        fpath_400 = os.path.join(OUT_400_DIR, fname_400)
        img_400.save(fpath_400, format="PNG")

        with open(fpath_512, "rb") as f:
            sha512 = hashlib.sha256(f.read()).hexdigest()
        with open(fpath_400, "rb") as f:
            sha400 = hashlib.sha256(f.read()).hexdigest()

        manifest_rows.append({
            "id": item["id"],
            "prompt": item["prompt"],
            "seed": item["seed"],
            "model": MODEL_ID,
            "scheduler": SCHEDULER,
            "steps": STEPS,
            "guidance": GUIDANCE,
            "height": HEIGHT,
            "width": WIDTH,
            "safety_checker": USE_SAFETY_CHECKER,
            "file_512": os.path.relpath(fpath_512, OUT_DIR),
            "sha256_512": sha512,
            "file_400": os.path.relpath(fpath_400, OUT_DIR),
            "sha256_400": sha400,
        })
# Out:
# Generating SD2.1 images:   0%|          | 0/1000 [00:00<?, ?it/s]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['octane render']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['cker , wlop , boris vallejo ))), octane render , unreal engine , 3 d render , macro mugshot !!!!!, ugly !!!!!!, octane render , nvidia raytracing demo , grainy , muted']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['draws']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['m , award - winning']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['on artstation pixiv makoto shinkai']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['enson , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['. 4 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['western comic book art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['shot , 8 k resolution , epic volumetric light , cinematography , concept art , artstation trending , environments , fantasy']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['society']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['explosions in the sky , no frames , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['m and greg rutkowski and alphonse mucha and william - adolphe bouguereau , craig mullins , j . c . leyendecker ”']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['se mucha , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['marc simonetti , krenz cushart , sakimichan , d & d trending on artstation , digital art .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['z cushart , sakimichan , d & d trending on artstation , digital art .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['ney and greg rutkowski']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', realistic military carrier']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', sharp focus , illustration , artgerm , tomasz alen kopera , wlop']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['octane render , weta digital , micro details , 3 d sculpture']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['autocad']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', concept art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['villeneuve']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['rutkowski']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['artstation , digital art .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['2 1 4 2 6 6 1 9 9 3 , 2 7 4 1 4 8 5 0 5 6 , 2 2 6 5 0 7 0 8 8 6 , 3 1 3 9 7 4 2 8 6 4 , 7 6 2 9 1 9 2 5 6 , 1 7 5 2 1 5 6 0 0 8 , 4 0 9 1 8 3 8 8 5 5 , 1 5 4 3 7 2 6 3 8 1 , 3 9 5 5 8 3 6 7 3 5 ]']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['painting , style by eddie mendoza , raphael lacoste , alex ross ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['gotouge']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['artstation , trending']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['masterpiece']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['m']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['detailed , intricate , epic composition , cinematic lighting , masterpiece , trending on artstation , very very detailed , masterpiece , stunning ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['photorealistic , volumetric lighting caustics , pink']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['symmetrical artwork , depth field , unreal engine , cinematic , hyper realism , high detail , octane cinema 4 d render , a 2 4 cinematography , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['tti , krenz cushart , sakimichan , d & d trending on artstation , digital art .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['intricate environment']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['very detailed , vibrant colors , art nouveau , masterpiece , romanticism']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', oil painting']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['alberto vargas , earl moran , enoch bolles']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', boris vallejo']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['therapy , trending on artstation , ink splatters , pen lines , incredible detail , creative , positive energy , happy , unique , negative space , pure imagination painted by artgerm']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['aesthetic , centered symmetrical and detailed']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['alsphonse mucha , artgerm']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['nicovideo , steven artgerm lau , wlop , rossdraws , ruanjia , james jean , andrei riabovitchev , totorrl , marc simonetti , visual key , and sakimichan']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', sharp , details , hyper - detailed , hd , 4 k , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['mucha']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['ray tracing , god rays']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['hyper detailed .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['mendoza , raphael lacoste , alex ross']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', 4 k , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['xiv , instagram , dribbble , artstationhd']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and sakimichan , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['focus , illustration , concept art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['pi']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['ji ito , by mina petrovic and artgerm']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['namco artist , macross frontier , dynamic camera angle , art deco patterns']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['. 8 k resolution . trending on artstation , trending on deviant art .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['lens effect .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['award winning , artstation , intricate details , realistic , hyperdetailed , 8 k resolution . concept painting . key art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['bius , fantasy , rule of thirds , fibonacci , intricate , cel shaded , flat , matte print , makoto shinkai']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['cinematic detail , composition , photorealistic , render in unreal engine 5 , golden ratio , 8 k render']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['adi meyers , thomas reimann , gaston bussiere']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['octane , under water visual distortion , dark tones colors , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', unreal engine 4 k , cinema 4 d ray traced 8 k fabric texture details , octane render']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['germ and greg rutkowski and alphonse mucha']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['ssiere']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['s']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['mythology , photorealistic , ernst fuchs , bodhisattva']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', art by artgerm and greg rutkowski and alphonse mucha']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['j . dickenson , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['hd , uplight']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['alphonse mucha , acid pixie']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['stunning , intricate detailed character . 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['artgerm , very coherent , triadic color scheme , art by takato yamamoto and james jean']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['etti , and sakimi chan , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['by artgerm']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['card']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', soft colors , relaxed colors , hyperdetailed , wide angle lens , fantasy , futuristic horror , armor style of giger']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['face , cinematic lighting']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['style , hyperrealism , hyper detailed']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and ross tran ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['joseph christian leyendecker drew struzan']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['wlop , mucha , james jean , victo ngai , ryohei hase']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['backlit , elegant']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['lighting , sharp focus , illustration , concept art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['.']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['ance ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['loish and wlop']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['composition , cinematic atmosphere , dynamic dramatic cinematic lighting , precise correct anatomy , aesthetic , very inspirational , arthouse']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['mus bosch , frans hals , rembrandt']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['sao h 6 4 0']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['richard hamilton']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['germ']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', stunning ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', and jinsung lim , luka mivsek']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['))), mugshot !!!!!, ugly !!!!!!, octane render , nvidia raytracing demo , grainy , muted , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['image']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', and sakimi chan , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['alphonse mucha']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and jin xiaodi']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['render , 8 k , high contrast , duo tone , depth of field , very coherent symmetrical artwork']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['draws']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['alphonse mucha , sunrise , new art nouveau , soft ambient lighting , particle effects']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['station , wizard , digital art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and orange glow , vibrant']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['in']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', brush hard , artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['lop']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', art by krenz cushart and albert aublet']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['octane']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['k , cinematic , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['mucha , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['illumination , circuit bent synthesis .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['guereau and beeple . key art . fantasy illustration . award winning , artstation , intricate details , realistic , hyperdetailed , 8 k resolution .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['painting , 8 k , illustration , painting , dramatic , beautiful , art by loish loish loish , cartoon , stylized painterly , trending on artstation , medium shot , uncropped']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', cinematic , masterpiece']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', very detailed , vibrant colors , art nouveau , masterpiece , romanticism']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', artstation , 8 k , unreal engine , hdr , concept art , matte , sharp focus ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', krenz cushart , sakimichan , d & d trending on artstation , digital art .']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['renz cushart']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['k , octane render ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', details , hyper - detailed , hd , 4 k , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['alphonse mucha and artgerm']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['tolab , affinity photo ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['art by artgem']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['quality , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', hyper realistic , octane render , raytracing , trending on artstation , artstationhd , artstationhq , unreal engine , 4 k , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['highly detailed , artstation , concept art , painterly , golden ratio , sharp focus']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['station , cgsociety contest winner , 4 k , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['digital art , trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', render in unreal engine 5 , golden ratio , 8 k render']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['vshinov , rossdraws , hd , 3 2 k , ilya kuvshinov , gustav klimt']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['water']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['jin xiaodi']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['scifi , detailed illustration , character portrait ,- c 8 . 5']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['mucha']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['render']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['station']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', art nouveau , mosaic , intricate | by mark maggiori ((( and alphonse mucha ))) | trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['tz , jack kirby , mysterious vibes']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and loish and wlop']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['wide angle , highly detailed , v - ray render , photorealistic , 4 k hd wallpaper']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and loish and wlop']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['face , real life']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and alphonse mucha']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', cinematic atmosphere , dynamic dramatic cinematic lighting , precise correct anatomy , aesthetic , very inspirational , arthouse']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['jim lee ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['hdr , 4 k , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['stanley artgerm , perfect smile and tooth']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', 4 k resolution , detail , high quality , clear focus , headquarters design , clear , crazy detail , concept art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['trending on artstation , masterpiece']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [',']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['trending on artstation']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [". balanced colors and lighting scheme by james gurney and artgerm . in the style of a 'm usic to chill / study ' to youtube video ."]
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', daily deviation ,']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['artstation , made in maya , blender and photoshop , octane render , excellent composition , cinematic atmosphere , dynamic dramatic cinematic lighting , aesthetic , very inspirational , arthouse']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['realistic']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['engine 5 , 8 k , art by art by artgerm and greg rutkowski and edgar maxence']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['arthouse']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['and alphonse mucha , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['.']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['. c . leyendecker , tom of finland']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['art']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['field parrish and alphonse mucha , new art nouveau , soft ambient lighting , tarot card']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['lighting , sharp , details , hyper - detailed , hd , hdr , 4 k , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', octane render , excellent composition , cinematic dystopian brutalist atmosphere , dynamic dramatic cinematic lighting , aesthetic , very inspirational , arthouse']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['3 0 9 0 , trending on artstation , lumens']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['2']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', dramatic color']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['rutkowski and alphonse mucha , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['mucha']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['lowe , trending on artstation and greg rutkowski and alphonse mucha , 8 k']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['kowski , wlop jeremy lipkin , giuseppe dangelico pino , michael garmash , rob rey']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: ['station']
# The following part of your input was truncated because CLIP can only handle sequences up to 77 tokens: [', octane , 8 k insane detail , style of monument valley , wes anderson']
